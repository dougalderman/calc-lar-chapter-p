# %%
#11

# %%
def f(x): return 1/(1-x)

# %%
plot(f(x),(x,-5,5),ymin=-20,ymax=20,detect_poles='show',legend_label='f(x)')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
def f2(x): return f(f(x))

# %%
f2(x)
# Out:
# 1/(1/(x - 1) + 1)

# %%
f2(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 f2(Integer(1))
#
# Cell In [8], line 1, in f2(x)
# ----> 1 def f2(x): return f(f(x))
#
# Cell In [6], line 1, in f(x)
# ----> 1 def f(x): return Integer(1)/(Integer(1)-x)
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f2(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 f2(Integer(0))
#
# Cell In [8], line 1, in f2(x)
# ----> 1 def f2(x): return f(f(x))
#
# Cell In [6], line 1, in f(x)
# ----> 1 def f(x): return Integer(1)/(Integer(1)-x)
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2021, in sage.rings.integer.Integer.__truediv__()
#    2019 elif type(right) is Rational:
#    2020     if mpq_sgn((<Rational>right).value) == 0:
# -> 2021         raise ZeroDivisionError("rational division by zero")
#    2022     # left * den(right) / num(right)
#    2023     y = <Rational> Rational.__new__(Rational)
#
# ZeroDivisionError: rational division by zero

# %%
f2(2)
# Out:
# 1/2

# %%
f2(-1)
# Out:
# 2

# %%
p=[]

# %%
p.append(plot(f2(x),(x,-5,5),ymin=-20,ymax=20,detect_poles='show',legend_label='f2(x)'))

# %%
p.append(plot(1,(-5,5),color='red',linestyle='--'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
def f3(x): return f(f(f(x)))

# %%
f3(x)
# Out:
# -1/(1/(1/(x - 1) + 1) - 1)

# %%
f3(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [29], line 1
# ----> 1 f3(Integer(0))
#
# Cell In [27], line 1, in f3(x)
# ----> 1 def f3(x): return f(f(f(x)))
#
# Cell In [6], line 1, in f(x)
# ----> 1 def f(x): return Integer(1)/(Integer(1)-x)
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2021, in sage.rings.integer.Integer.__truediv__()
#    2019 elif type(right) is Rational:
#    2020     if mpq_sgn((<Rational>right).value) == 0:
# -> 2021         raise ZeroDivisionError("rational division by zero")
#    2022     # left * den(right) / num(right)
#    2023     y = <Rational> Rational.__new__(Rational)
#
# ZeroDivisionError: rational division by zero

# %%
f3(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 f3(Integer(1))
#
# Cell In [27], line 1, in f3(x)
# ----> 1 def f3(x): return f(f(f(x)))
#
# Cell In [6], line 1, in f(x)
# ----> 1 def f(x): return Integer(1)/(Integer(1)-x)
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f3(2)
# Out:
# 2

# %%
f3(-1)
# Out:
# -1

# %%
plot(f3(x),(x,-5,5),ymin=-20,ymax=20,legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#15

# %%
var('x y')
# Out:
# (x, y)

# %%
def f(x,y): return (x^2 + y^2)^2 - 2*(x^2 - y^2)

# %%
implicit_plot(f(x,y), (-3,3), (-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x,0)
# Out:
# x^4 - 2*x^2

# %%
solve(x^4 - 2*x^2==0,x)
# Out:
# [x == -sqrt(2), x == sqrt(2), x == 0]
