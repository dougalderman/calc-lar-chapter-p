# %%
#Problem 47

# %%
x=SR.var('x')

# %%
def f(x): return x^3 - 3*x^2

# %%
plot(f(x),(x,-3,3),ymin=-10,ymax=10,legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#Problem 48

# %%
x=SR.var('x')

# %%
def f(x): return x

# %%
def g(x): return x^3

# %%
def h(x): return x^5

# %%
p=[]

# %%
p.append(plot(f(x),(x,-3,3),ymin=-10,ymax=10,color='blue',legend_label='f(x)'))

# %%
p.append(plot(g(x),(x,-3,3),ymin=-10,ymax=10,color='green',legend_label='g(x)'))

# %%
p.append(plot(h(x),(x,-3,3),ymin=-10,ymax=10,color='red',legend_label='h(x)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
def f2(x): return x^2

# %%
def g2(x): return x^4

# %%
def h2(x): return x^6

# %%
q=[]

# %%
q.append(plot(f2(x),(x,-3,3),ymin=-10,ymax=10,color='blue',legend_label='f2(x)'))

# %%
q.append(plot(g2(x),(x,-3,3),ymin=-10,ymax=10,color='green',legend_label='g2(x)'))

# %%
q.append(plot(h2(x),(x,-3,3),ymin=-10,ymax=10,color='red',legend_label='h2(x)'))

# %%
sum(q)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
def i(x): return x^7

# %%
p.append(plot(i(x),(x,-3,3),ymin=-10,ymax=10,color='orange',legend_label='i(x)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
def i2(x): return x^8

# %%
q.append(plot(i2(x),(x,-3,3),ymin=-10,ymax=10,color='orange',legend_label='i2(x)'))

# %%
sum(q)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
#Problem 49

# %%
x=SR.var('x')

# %%
def f3(x): return (x^2)*((x-6)^2)

# %%
plot(f3(x),(x,-3,3),ymin=-10,ymax=10,color='blue',legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def f4(x): return x^4 - 12*x^3 + 36*x^2

# %%
plot(f4(x),(x,-3,3),ymin=-10,ymax=10,color='blue',legend_label='f4(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f3(x),(x,-10,10),ymin=-100,ymax=100,color='blue',legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def g3(x): return (x^3)*((x-6)^2)

# %%
plot(g3(x),(x,-3,3),ymin=-10,ymax=10,color='blue',legend_label='g3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(g3(x),(x,-10,10),ymin=-100,ymax=300,color='blue',legend_label='g3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def h3(x): return (x^3)*((x-6)^3)

# %%
plot(h3(x),(x,-3,3),ymin=-10,ymax=10,color='blue',legend_label='h3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(h3(x),(x,-10,10),ymin=-800,ymax=200,color='blue',legend_label='h3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#Problem 53

# %%
t=var('t')

# %%
def f(t): return 0.25*cos((2*pi*t)/1.1)

# %%
plot(f(t),(t,0,2),ymin=-0.5,ymax=0.5,legend_label='f(t)')
# Out:
# Graphics object consisting of 1 graphics primitive
