# %%
#Problem 37

# %%
x = var('x')

# %%
def f(x): return sqrt(9 - x^2)

# %%
plot(f(x),(x,-3,3),legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#Problem 81

# %%
x = var('x')

# %%
def f(x): return x * cos(x)

# %%
plot(f(x),(x,-10,10),legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive
